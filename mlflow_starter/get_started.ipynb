# %% [markdown]
# ##MLFLOW TRACKING SERVER

# %%
import mlflow

# %%
mlflow.set_tracking_uri("http://127.0.0.1:5001")

# %%
mlflow.set_experiment("Check local host connection")
with mlflow.start_run():
    mlflow.log_metric("sanskar",6)
    mlflow.log_metric("tushar",11)
# Out:
# 🏃 View run indecisive-slug-379 at: http://127.0.0.1:5001/#/experiments/785206439212412628/runs/d95e0f08b323470485ba683ac991dd2c
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/785206439212412628

# %%
mlflow.set_experiment("Check local host connection again")
with mlflow.start_run():
    mlflow.log_metric("rachna",2)
    mlflow.log_metric("poonam",9)
# Out:
# 🏃 View run nosy-penguin-375 at: http://127.0.0.1:5001/#/experiments/958021610471578279/runs/b147bf13638148b0af4ea5434a3acb28
# 🧪 View experiment at: http://127.0.0.1:5001/#/experiments/958021610471578279
